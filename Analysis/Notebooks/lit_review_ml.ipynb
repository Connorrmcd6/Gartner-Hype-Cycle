# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
path = '/Users/connormcdonald/Desktop/Masters/MIT807/Gartner Repository/Analysis/Figures'
import matplotlib
from mpl_toolkits.axisartist.axislines import SubplotZero
from pylab import text
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "lualatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

# %%
df = pd.read_csv('/Users/connormcdonald/Desktop/Masters/MIT807/Data/compute.csv')

# %%
#ML plot
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_yscale('log')
plt.rcParams["figure.figsize"] = [4, 4]
plt.rcParams.update({'font.size': 12})
plt.rcParams['figure.dpi'] = 300
plt.xlabel('Year')
plt.ylabel('Computing Power (MSOPS)')
plt.scatter(df['year'], df['MSOPS'], c = '#003366', s = 5)

plt.savefig(os.path.join(path, 'compute_power.pdf'), format='pdf',bbox_inches='tight',pad_inches = 0)
plt.close()

# %%
#ML plot
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_yscale('log')
plt.rcParams["figure.figsize"] = [4, 4]
plt.rcParams.update({'font.size': 12})
plt.rcParams['figure.dpi'] = 300
plt.xlabel('Year')
plt.ylabel('Cost Per MSOP (\$)')
plt.scatter(df['year'], df['MSOPS_cost'], c = '#003366', s = 5)

plt.savefig(os.path.join(path, 'compute_cost.pdf'), format='pdf',bbox_inches='tight',pad_inches = 0)
plt.close()

# %%
print(df.to_latex(index=False))
# Out:
# \begin{tabular}{rrr}
# \toprule
#  year &        MSOPS &   MSOPS\_cost \\
# \midrule
#  1880 & 1.680000e-08 & 5.683257e+04 \\
#  1857 & 1.340000e-07 & 3.992375e+04 \\
#  1874 & 1.870000e-08 & 3.972284e+04 \\
#  1890 & 3.130000e-07 & 7.939779e+04 \\
#  1895 & 2.590000e-07 & 3.985048e+03 \\
#  1902 & 1.480000e-06 & 2.348287e+04 \\
#  1905 & 6.720000e-08 & 1.617505e+04 \\
#  1907 & 3.870000e-07 & 2.720478e+04 \\
#  1911 & 2.910000e-08 & 6.769579e+04 \\
#  1919 & 5.330000e-08 & 6.769579e+04 \\
#  1935 & 1.000000e-06 & 5.085362e+04 \\
#  1938 & 4.450000e-08 & 4.791160e+05 \\
#  1939 & 4.450000e-07 & 4.915028e+04 \\
#  1939 & 1.990000e-06 & 2.413768e+04 \\
#  1940 & 3.330000e-06 & 8.670314e+03 \\
#  1941 & 1.340000e-06 & 2.554267e+04 \\
#  1942 & 2.030000e-06 & 5.965127e+04 \\
#  1942 & 6.960000e-06 & 1.399368e+03 \\
#  1943 & 1.100000e-06 & 4.081566e+04 \\
#  1943 & 3.020000e-06 & 4.089901e+04 \\
#  1943 & 2.290000e-04 & 3.109659e+02 \\
#  1944 & 2.480000e-06 & 1.602959e+05 \\
# ...
